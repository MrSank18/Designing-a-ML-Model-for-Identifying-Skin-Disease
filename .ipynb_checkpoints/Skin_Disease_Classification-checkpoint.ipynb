# %% [markdown]
# Downloading the dataset

# %%
# !kaggle datasets download -d subirbiswas19/skin-disease-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/subirbiswas19/skin-disease-dataset
# License(s): CC0-1.0
# Downloading skin-disease-dataset.zip to C:\Users\abhilash\OneDrive\Desktop\Project2
#   0%|          | 0.00/17.3M [00:00<?, ?B/s]
#   6%|5         | 1.00M/17.3M [00:02<00:40, 417kB/s]
#  12%|#1        | 2.00M/17.3M [00:06<00:55, 290kB/s]
#  17%|#7        | 3.00M/17.3M [00:10<00:50, 294kB/s]
#  23%|##3       | 4.00M/17.3M [00:13<00:45, 309kB/s]
#  29%|##8       | 5.00M/17.3M [00:16<00:40, 320kB/s]
#  35%|###4      | 6.00M/17.3M [00:21<00:43, 274kB/s]
#  40%|####      | 7.00M/17.3M [00:25<00:39, 270kB/s]
#  46%|####6     | 8.00M/17.3M [00:29<00:36, 265kB/s]
#  52%|#####2    | 9.00M/17.3M [00:32<00:29, 299kB/s]
#  58%|#####7    | 10.0M/17.3M [00:34<00:23, 327kB/s]
#  64%|######3   | 11.0M/17.3M [00:37<00:18, 354kB/s]
#  69%|######9   | 12.0M/17.3M [00:38<00:13, 412kB/s]
#  75%|#######5  | 13.0M/17.3M [00:40<00:09, 458kB/s]
#  81%|########  | 14.0M/17.3M [00:42<00:07, 475kB/s]
#  87%|########6 | 15.0M/17.3M [00:46<00:06, 395kB/s]
#  93%|#########2| 16.0M/17.3M [00:51<00:04, 291kB/s]
#  98%|#########8| 17.0M/17.3M [00:56<00:01, 277kB/s]
# 100%|##########| 17.3M/17.3M [00:56<00:00, 287kB/s]
# 100%|##########| 17.3M/17.3M [00:56<00:00, 319kB/s]

# %%
from zipfile import ZipFile

with ZipFile("skin-disease-dataset.zip", "r") as zip_ref:
  zip_ref.extractall()

# %% [markdown]
# Checking no of images

# %%
import os
train_dir  =r"C:\Users\abhilash\OneDrive\Desktop\Project2\skin-disease-datasaet\train_set"
total_train_images  =0

for category in os.listdir(train_dir):
    category_dir = os.path.join(train_dir, category)
    num_images = len(os.listdir(category_dir))
    total_train_images += num_images

print("Total no of training images: ", total_train_images)
# Out:
# Total no of training images:  925

# %%
test_dir = r"C:\Users\abhilash\OneDrive\Desktop\Project2\skin-disease-datasaet\test_set"
total_test_images  =0

for category in os.listdir(test_dir):
  category_dir = os.path.join(test_dir , category)
  num_images = len(os.listdir(category_dir))
  total_test_images += num_images

print("Total no of test images: ", total_test_images)
# Out:
# Total no of test images:  234

# %% [markdown]
# Seeing some sample images

# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to the image
img_dir = r"C:\Users\abhilash\OneDrive\Desktop\project2\skin-disease-datasaet\test_set\VI-shingles\127_VI-shingles (32).jpg"

# Read the image
img = mpimg.imread(img_dir)

# Display the image with a title
plt.imshow(img)
plt.axis("off")  # Turn off axis
plt.title("shingles Disease (128 * 128 PX )", fontsize=14, color="blue")  # Add a title above the image
plt.show()



print(end =" ")


img_dir = r"C:\Users\abhilash\OneDrive\Desktop\project2\skin-disease-datasaet\test_set\BA-impetigo\64_BA-impetigo (2).png"

# Read the image
img = mpimg.imread(img_dir)

# Display the image with a title
plt.imshow(img)
plt.axis("off")  # Turn off axis
plt.title("Impetigo Disease (128 * 128 PX )", fontsize=14, color="blue")  # Add a title above the image
plt.show()

# %%
print(img.shape)
# Out:
# (207, 207, 3)

# %% [markdown]
# Using Data Generators  - Helping in Data Augmentation

# %%
#DEFINING THE DATA GENERATOR
from keras.preprocessing.image import ImageDataGenerator
data_gen = ImageDataGenerator(
    rescale = 1./255,
)

# %%
#Defining the training set data generator

train_dir  =r"C:\Users\abhilash\OneDrive\Desktop\Project2\skin-disease-datasaet\train_set"

train_generator = data_gen.flow_from_directory(
    train_dir,
    target_size =(150, 150),
    class_mode="categorical",
    batch_size = 32
)
# Out:
# Found 924 images belonging to 8 classes.

# %%
#Defining the test set generator

test_dir = r"C:\Users\abhilash\OneDrive\Desktop\Project2\skin-disease-datasaet\test_set"

test_generator = data_gen.flow_from_directory(
    test_dir,
    target_size = (150,150),
    class_mode="categorical",
    batch_size = 32
)
# Out:
# Found 233 images belonging to 8 classes.

# %% [markdown]
# Building the CNN

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation="relu", input_shape =(150, 150,3), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, (3,3), activation="relu", input_shape =(150, 150,3), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))



model.add(Conv2D(128, (3,3), activation="relu", input_shape =(150, 150,3), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128, (3,3), activation="relu", input_shape =(150, 150,3), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Conv2D(512, (3,3), activation="relu", input_shape =(150, 150,3), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Conv2D(512, (3,3), activation="relu", input_shape =(150, 150,3), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.6))
model.add(Dense(128, activation ="relu"))
model.add(Dropout(0.6))
model.add(Dense(8, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  batch_normalization (BatchN  (None, 150, 150, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 75, 75, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 37, 37, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 18, 18, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 9, 9, 512)         590336
#
#  batch_normalization_4 (Batc  (None, 9, 9, 512)        2048
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 512)         2359808
#
#  batch_normalization_5 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 4,312,264
# Trainable params: 4,309,512
# Non-trainable params: 2,752
# _________________________________________________________________

# %% [markdown]
# Model Compiling

# %%
from keras.optimizers import Adam
model.compile(loss="categorical_crossentropy", optimizer ="adam", metrics=["accuracy"])

# %% [markdown]
# Model Training

# %%
history  = model.fit(train_generator, epochs = 25, batch_size = 15, validation_data = test_generator)
# Out:
# Epoch 1/25
# 29/29 [==============================] - 56s 2s/step - loss: 4.4513 - accuracy: 0.1742 - val_loss: 2.2634 - val_accuracy: 0.1588
# Epoch 2/25
# 29/29 [==============================] - 51s 2s/step - loss: 2.7355 - accuracy: 0.2273 - val_loss: 2.2362 - val_accuracy: 0.0987
# Epoch 3/25
# 29/29 [==============================] - 51s 2s/step - loss: 2.2564 - accuracy: 0.2597 - val_loss: 2.5924 - val_accuracy: 0.1459
# Epoch 4/25
# 29/29 [==============================] - 51s 2s/step - loss: 2.1651 - accuracy: 0.3041 - val_loss: 2.3042 - val_accuracy: 0.0987
# Epoch 5/25
# 29/29 [==============================] - 51s 2s/step - loss: 1.9182 - accuracy: 0.3344 - val_loss: 3.0784 - val_accuracy: 0.0987
# Epoch 6/25
# 29/29 [==============================] - 52s 2s/step - loss: 1.8134 - accuracy: 0.3669 - val_loss: 2.4093 - val_accuracy: 0.0987
# Epoch 7/25
# 29/29 [==============================] - 55s 2s/step - loss: 1.7048 - accuracy: 0.3950 - val_loss: 3.0607 - val_accuracy: 0.0987
# Epoch 8/25
# 29/29 [==============================] - 54s 2s/step - loss: 1.7170 - accuracy: 0.4177 - val_loss: 3.0209 - val_accuracy: 0.0987
# Epoch 9/25
# 29/29 [==============================] - 54s 2s/step - loss: 1.5729 - accuracy: 0.4513 - val_loss: 2.6274 - val_accuracy: 0.1030
# Epoch 10/25
# 29/29 [==============================] - 53s 2s/step - loss: 1.4927 - accuracy: 0.4697 - val_loss: 2.2223 - val_accuracy: 0.1116
# Epoch 11/25
# 29/29 [==============================] - 53s 2s/step - loss: 1.4275 - accuracy: 0.4697 - val_loss: 2.2886 - val_accuracy: 0.2103
# Epoch 12/25
# 29/29 [==============================] - 53s 2s/step - loss: 1.2575 - accuracy: 0.5498 - val_loss: 2.1791 - val_accuracy: 0.2489
# Epoch 13/25
# 29/29 [==============================] - 52s 2s/step - loss: 1.1937 - accuracy: 0.5693 - val_loss: 2.4765 - val_accuracy: 0.2704
# Epoch 14/25
# 29/29 [==============================] - 52s 2s/step - loss: 1.1777 - accuracy: 0.5877 - val_loss: 2.0299 - val_accuracy: 0.2446
# Epoch 15/25
# 29/29 [==============================] - 52s 2s/step - loss: 1.1559 - accuracy: 0.5974 - val_loss: 1.7617 - val_accuracy: 0.3219
# Epoch 16/25
# 29/29 [==============================] - 51s 2s/step - loss: 0.9915 - accuracy: 0.6342 - val_loss: 1.8439 - val_accuracy: 0.3863
# Epoch 17/25
# 29/29 [==============================] - 53s 2s/step - loss: 0.8719 - accuracy: 0.6991 - val_loss: 1.8942 - val_accuracy: 0.3734
# Epoch 18/25
# 29/29 [==============================] - 51s 2s/step - loss: 0.9013 - accuracy: 0.6569 - val_loss: 2.2369 - val_accuracy: 0.3648
# Epoch 19/25
# 29/29 [==============================] - 51s 2s/step - loss: 0.7608 - accuracy: 0.7316 - val_loss: 1.4296 - val_accuracy: 0.5494
# Epoch 20/25
# 29/29 [==============================] - 52s 2s/step - loss: 0.8044 - accuracy: 0.7338 - val_loss: 1.2679 - val_accuracy: 0.5966
# Epoch 21/25
# 29/29 [==============================] - 51s 2s/step - loss: 0.7314 - accuracy: 0.7554 - val_loss: 1.3896 - val_accuracy: 0.6309
# Epoch 22/25
# 29/29 [==============================] - 51s 2s/step - loss: 0.7475 - accuracy: 0.7630 - val_loss: 1.5424 - val_accuracy: 0.5021
# Epoch 23/25
# 29/29 [==============================] - 51s 2s/step - loss: 0.5592 - accuracy: 0.8268 - val_loss: 1.0400 - val_accuracy: 0.6395
# Epoch 24/25
# 29/29 [==============================] - 51s 2s/step - loss: 0.5425 - accuracy: 0.8160 - val_loss: 1.3654 - val_accuracy: 0.6395
# Epoch 25/25
# 29/29 [==============================] - 52s 2s/step - loss: 0.5333 - accuracy: 0.8323 - val_loss: 3.7890 - val_accuracy: 0.3391

# %%
h = history

plt.plot(h.history["accuracy"])
plt.plot(h.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# %%
model.save("skin_disease_model.h5")
